# %%
# import des bibliotheques
# import bibliothéques d'analyse de python
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from matplotlib.ticker import FuncFormatter
import seaborn as sns
import numpy as np

import fonctions.perso_stats as perso_stats
import fonctions.perso_reg_lin as perso_reg_lin

# %%
# import des fichiers
                                              
college = pd.read_csv('donnee_temp/college.csv',low_memory=False)

# %%
# style graphe :
sns.set_theme(style="whitegrid")
#plt.style.use("dark_background")
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
sns.set_palette("pastel")
palette = sns.color_palette("pastel").as_hex()

# %%
college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32984 entries, 0 to 32983
# Data columns (total 63 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Rentrée scolaire                               32984 non-null  int64
#  1   Région                                         32982 non-null  object
#  2   Académie                                       32982 non-null  object
#  3   Département                                    32982 non-null  object
#  4   Commune                                        32982 non-null  object
#  5   UAI                                            32984 non-null  object
#  6   Dénomination principale                        32982 non-null  object
#  7   Patronyme                                      32927 non-null  object
#  8   Secteur                                        32982 non-null  object
#  9   REP                                            32982 non-null  float64
#  10  REP +                                          32982 non-null  float64
#  11  Nombre d'élèves total                          32982 non-null  float64
#  12  Nombre d'élèves total hors Segpa hors ULIS     32982 non-null  float64
#  13  Nombre d'élèves total Segpa                    32982 non-null  float64
#  14  Nombre d'élèves total ULIS                     32982 non-null  float64
#  15  6èmes total                                    32982 non-null  float64
#  16  6èmes hors Segpa hors ULIS                     32982 non-null  float64
#  17  6èmes Segpa                                    32982 non-null  float64
#  18  6èmes ULIS                                     32982 non-null  float64
#  19  6èmes filles                                   32982 non-null  float64
#  20  6èmes garçons                                  32982 non-null  float64
#  21  6ème LV2 autres langues                        32982 non-null  float64
#  22  5èmes total                                    32982 non-null  float64
#  23  5èmes hors Segpa hors ULIS                     32982 non-null  float64
#  24  5èmes Segpa                                    32982 non-null  float64
#  25  5èmes ULIS                                     32982 non-null  float64
#  26  5èmes filles                                   32982 non-null  float64
#  27  5èmes garçons                                  32982 non-null  float64
#  28  4èmes total                                    32982 non-null  float64
#  29  4èmes hors Segpa hors ULIS                     32982 non-null  float64
#  30  4èmes Segpa                                    32982 non-null  float64
#  31  4èmes ULIS                                     32982 non-null  float64
#  32  4èmes filles                                   32982 non-null  float64
#  33  4èmes garçons                                  32982 non-null  float64
#  34  3èmes total                                    32982 non-null  float64
#  35  3èmes hors Segpa hors ULIS                     32982 non-null  float64
#  36  3èmes Segpa                                    32982 non-null  float64
#  37  3èmes ULIS                                     32982 non-null  float64
#  38  3èmes filles                                   32982 non-null  float64
#  39  3èmes garçons                                  32982 non-null  float64
#  40  Code postal                                    32862 non-null  float64
#  41  Code INSEE de la commune                       6973 non-null   object
#  42  Effectifs                                      6973 non-null   float64
#  43  IPS                                            6973 non-null   float64
#  44  Ecart-type de l'IPS                            6973 non-null   float64
#  45  Nb candidats - G                               13237 non-null  float64
#  46  Taux de réussite - G                           13237 non-null  float64
#  47  VA du taux de réussite - G                     12712 non-null  float64
#  48  Nb candidats - P                               4013 non-null   float64
#  49  Taux de réussite - P                           4013 non-null   float64
#  50  Note à l'écrit - G                             13237 non-null  float64
#  51  VA de la note - G                              12712 non-null  float64
#  52  Note à l'écrit - P                             4013 non-null   float64
#  53  Taux d'accès 6ème-3ème                         13216 non-null  float64
#  54  Part présents 3ème ordinaire - Total           13237 non-null  float64
#  55  Part présents 3ème ordinaire - G               6621 non-null   float64
#  56  Part présents 3ème ordinaire - P               2100 non-null   float64
#  57  Part présents 3ème Segpa - Total               2809 non-null   float64
#  58  Nb mentions AB - G                             13237 non-null  float64
#  59  Nb mentions B - G                              13237 non-null  float64
#  60  Nb mentions TB - G                             13237 non-null  float64
#  61  Nb mentions global - G                         13237 non-null  float64
#  62  Pourcentage Ulis sur le nombre d'eleves total  32982 non-null  float64
# dtypes: float64(53), int64(1), object(9)
# memory usage: 15.9+ MB

# %% [markdown]
# Dans la partie Analyse, il y a une colonne valeur ajoutée des colléges.<br>
# Ce noteboook va tenter de refaire cette colonne.<br>
# Selon la notice ils ont utilisé :
# <ul>
#     <li>IPS : Indice de position Sociale</li>
#     <li>le sexe des éléves</li>
#     <li>les résultats des évaluation de sixieme</li>
#     <li>les retards des élèves</li>
# </ul>
# Il ont prédit les résultats puis il ont fait la différences entre les prediction et les résultats réels.<br>
# Je n ai accès que aux sexe et à l'IPS. Mais testons ça.<br>

# %%
# prepa donne en mode rache : les données ayant pas de resultats utre que 2022 + college sans donnée
college2022 = college[college['Rentrée scolaire']==2022].copy()
college2022 = college2022[['VA de la note - G','3èmes filles','3èmes total','IPS',"Note à l'écrit - G",'Secteur',"Pourcentage Ulis sur le nombre d'eleves total"]]
college2022.dropna(inplace=True)

# %%
# distributon va de la note
fig,ax =plt.subplots()
sns.histplot(college2022,x='VA de la note - G',ax=ax)
ax.set_title('distribution de la valeur ajoutée')
plt.show()
del fig,ax

# %%
# test normalité valeur ajouté
rep = perso_stats.test_loi_normale(college2022['VA de la note - G'].sample(5000))
del rep
# Out:
# Interprétation du test:
# H0 : La série suit une loi Normale
# H1 : La série ne suit pas une loi Normale
# Étant donné que la p-values est inférieure au niveau de signification alpha = 0.05 ,
# on doit rejeter l'hypothèse nulle H0 et retenir l'hypothèse H1.
# Le risque de rejeter l'hypothèse nulle H0 alors qu'elle est vraie est inferieur à  0.0 %

# %%
print('la valeur ajoutée maximale est de :',college2022["VA de la note - G"].max())
# Out:
# la valeur ajoutée maximale est de : 3.3

# %%
print('la valeur ajoutée minimale est de :',college2022["VA de la note - G"].min())
# Out:
# la valeur ajoutée minimale est de : -3.0

# %%
college2022.corr(numeric_only=True)
# Out:
#                                                VA de la note - G  \
# VA de la note - G                                       1.000000
# 3èmes filles                                           -0.093900
# 3èmes total                                            -0.101398
# IPS                                                     0.017461
# Note à l'écrit - G                                      0.485964
# Pourcentage Ulis sur le nombre d'eleves total          -0.079393
#
#                                                3èmes filles  3èmes total  \
# VA de la note - G                                 -0.093900    -0.101398
# 3èmes filles                                       1.000000     0.963959
# 3èmes total                                        0.963959     1.000000
# IPS                                                0.177618     0.169623
# Note à l'écrit - G                                 0.092927     0.065161
# Pourcentage Ulis sur le nombre d'eleves total     -0.028998    -0.011900
#
#                                                     IPS  Note à l'écrit - G  \
# VA de la note - G                              0.017461            0.485964
# 3èmes filles                                   0.177618            0.092927
# 3èmes total                                    0.169623            0.065161
# IPS                                            1.000000            0.793683
# Note à l'écrit - G                             0.793683            1.000000
# Pourcentage Ulis sur le nombre d'eleves total -0.268176           -0.226550
#
#                                                Pourcentage Ulis sur le nombre d'eleves total
# VA de la note - G                                                                  -0.079393
# 3èmes filles                                                                       -0.028998
# 3èmes total                                                                        -0.011900
# IPS                                                                                -0.268176
# Note à l'écrit - G                                                                 -0.226550
# Pourcentage Ulis sur le nombre d'eleves total                                       1.000000

# %% [markdown]
# La valeurs ajouté ne sont pas distribué de façon normale.

# %%
# test juste avec ips
data_reg_lin = college2022[['IPS',"Note à l'écrit - G"]].copy()
reg_lin = perso_reg_lin.regression_lineaire(data=data_reg_lin,colonne_cible="Note à l'écrit - G",intercept=True)
# Out:
# intercept (const dans statmodels) 3.7199468395485615
# Coefficients:
#  [0.07349661]
# Erreur des moindres carrés train : 0.83
# Coefficient de determination train : 0.63
# erreur max train:  3.9909882248032655
#  test de Normalité des erreurs
#
#
# Interprétation du test:
# H0 : La série suit une loi Normale
# H1 : La série ne suit pas une loi Normale
# Étant donné que la p-values est inférieure au niveau de signification alpha = 0.05 ,
# on doit rejeter l'hypothèse nulle H0 et retenir l'hypothèse H1.
# Le risque de rejeter l'hypothèse nulle H0 alors qu'elle est vraie est inferieur à  0.0 %

# %% [markdown]
# Bon juste avec l'IPS on obtient déjà des resultats sympas : <br>
# <ul>
# <li>erreur des moindre carré : inférieur à 1 :globalement on est proche de la note réel.</li>
# <li>erreurs max d'environ 4 points pas terrible dans certain cas</li>
# </ul>
# Si on compare rapidement avec les va des colleges :
# <ul>
#     <li>les erreurs de la valeur ajouté des notes ressemble étrangement au erreurs de la regression linéaire</li>
#     <li>les erreurs max sont supérieures avec mon modéle.</li>
# </ul>
#
# Bon essayons d'amèliorrer la regression linéaire.

# %%
#regression lineaire avec le sexe des eleves + ips

college2022['Pourcentage fille'] = college2022['3èmes filles']/college2022['3èmes total']*100
data_reg_sex_ips = college2022[['IPS',"Note à l'écrit - G",'Pourcentage fille']].copy()
fig,ax = plt.subplots()
sns.heatmap(data_reg_sex_ips.corr(),ax=ax)
ax.set_title('Matrice de correlation',pad=30)
plt.show()

# %%
sns.heatmap(college2022.corr(numeric_only=True)[["Note à l'écrit - G"]].sort_values(by="Note à l'écrit - G",ascending=False),annot=True);

# %%
reg_lin_ips_sexe = perso_reg_lin.regression_lineaire(data=data_reg_sex_ips,colonne_cible="Note à l'écrit - G",intercept=True)
# Out:
# intercept (const dans statmodels) 2.755779959987878
# Coefficients:
#  [0.07328719 0.01988983]
# Erreur des moindres carrés train : 0.82
# Coefficient de determination train : 0.64
# erreur max train:  4.0751282645770015
#  test de Normalité des erreurs
#
#
# Interprétation du test:
# H0 : La série suit une loi Normale
# H1 : La série ne suit pas une loi Normale
# Étant donné que la p-values est inférieure au niveau de signification alpha = 0.05 ,
# on doit rejeter l'hypothèse nulle H0 et retenir l'hypothèse H1.
# Le risque de rejeter l'hypothèse nulle H0 alors qu'elle est vraie est inferieur à  0.0 %

# %% [markdown]
# Le sexe des filles ne permets pas d'ameliorrer enormément le modéle.

# %%
data_reg_ips_sex_ulis = college2022.copy()
data_reg_ips_sex_ulis.drop(columns=['Secteur',"VA de la note - G",'3èmes filles','3èmes total'],inplace=True)
reg_lin_ips_sex_ulis = perso_reg_lin.regression_lineaire(data=data_reg_ips_sex_ulis,colonne_cible="Note à l'écrit - G",intercept=True)
# Out:
# intercept (const dans statmodels) 2.803156637153
# Coefficients:
#  [ 0.07303099 -0.00983375  0.01975739]
# Erreur des moindres carrés train : 0.82
# Coefficient de determination train : 0.64
# erreur max train:  4.055730479686215
#  test de Normalité des erreurs
#
#
# Interprétation du test:
# H0 : La série suit une loi Normale
# H1 : La série ne suit pas une loi Normale
# Étant donné que la p-values est inférieure au niveau de signification alpha = 0.05 ,
# on doit rejeter l'hypothèse nulle H0 et retenir l'hypothèse H1.
# Le risque de rejeter l'hypothèse nulle H0 alors qu'elle est vraie est inferieur à  0.0 %

# %%
college2022['valeur_predite_reg_lin'] = reg_lin_ips_sex_ulis.predict(college2022[['IPS',"Pourcentage Ulis sur le nombre d'eleves total",'Pourcentage fille']])
college2022['différence_reglin_note'] = college2022["Note à l'écrit - G"]-college2022['valeur_predite_reg_lin']

# %%
college2022['différence_va_reglin'] = college2022["VA de la note - G"]-college2022['différence_reglin_note']

# %%
# difference entre les modeles
fig,ax =plt.subplots()
sns.histplot(college2022,x='différence_va_reglin',ax=ax)
ax.set_title('Différence entre les 2 modéles')
plt.show()
del fig,ax

# %% [markdown]
# Mon modèle a l'air assez proche du modèle utilisé par la VA. Il faut noter un écart de plus ou moins un point en moyenne entre les 2.

# %%
fig,ax = plt.subplots()
sns.boxplot(data=college2022, y="différence_reglin_note",ax=ax)
ax.set_title("Valeur ajouté du point de vu des notes à l'écrit en 2022 ",pad=50)
ax.set_ylabel("Valeur ajouté des colléges par reg_lin")
ax.set_xlabel("Année 2022")
plt.show()

# %%
fig,ax = plt.subplots()
sns.boxplot(data=college2022,x='Secteur', y="différence_reglin_note",ax=ax)
ax.set_title("Valeur ajouté du point de vu des notes à l'écrit en 2022 ",pad=50)
ax.set_ylabel("Valeur ajouté des colléges par reg_lin")
ax.set_xlabel("Année 2022")
plt.show()

# %% [markdown]
# Je n'arrive pas à faire mieux que l'indicateur du gouvernment. Le modéle utilisé pour calculer la VA à l'air d'être une regression linéaire avec plus de données.<br>
